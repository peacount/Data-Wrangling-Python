# %%
import os
os.chdir("C://Users//jenny//venvs//py39//Lib//site-packages")
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
# reading the csv file
os.chdir("C://Users//jenny//venvs//py39//data-wrangling-python//03//demos")
titanic = pd.read_csv("titanic.csv")

# %%
# first 5 rows
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  Parch  \
# 0                            Braund, Mr. Owen Harris    male  22.0      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#       Fare Embarked
# 0   7.2500        S
# 1  71.2833        C
# 2   7.9250        S
# 3  53.1000        S
# 4   8.0500        S

# %%
# number of unique values

titanic["Pclass"].nunique()
# Out:
# 3

# %%
# number of people who survived

titanic["Survived"].sum()
# Out:
# 342

# %%
titanic.groupby("Pclass")

# %%
titanic_class = titanic.groupby("Pclass")

# %%
titanic_class

# %%
for emb, titanic_df in titanic_class:
    print(emb)
    print(titanic_df)
# Out:
# 1
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#         Fare Embarked
# 1    71.2833        C
# 3    53.1000        S
# 6    51.8625        S
# 11   26.5500        S
# 23   35.5000        S
# ..       ...      ...
# 871  52.5542        S
# 872   5.0000        S
# 879  83.1583        C
# 887  30.0000        S
# 889  30.0000        C
#
# [216 rows x 9 columns]
# 2
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex   Age  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 17                   Williams, Mr. Charles Eugene    male   NaN      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0
# 21                          Beesley, Mr. Lawrence    male  34.0      0
# ..                                            ...     ...   ...    ...
# 866                  Duran y More, Miss. Asuncion  female  27.0      0
# 874         Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      0
# 880  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      1
# 883                 Banfield, Mr. Frederick James    male  28.0      0
# 886                         Montvila, Rev. Juozas    male  27.0      0
#
#         Fare Embarked
# 9    30.0708        C
# 15   16.0000        S
# 17   13.0000        S
# 20   26.0000        S
# 21   13.0000        S
# ..       ...      ...
# 866  13.8583        C
# 874  24.0000        C
# 880  26.0000        S
# 883  10.5000        S
# 886  13.0000        S
#
# [184 rows x 9 columns]
# 3
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  Parch     Fare Embarked
# 0      male  22.0      0   7.2500        S
# 2    female  26.0      0   7.9250        S
# 4      male  35.0      0   8.0500        S
# 5      male   NaN      0   8.4583        Q
# 7      male   2.0      1  21.0750        S
# ..      ...   ...    ...      ...      ...
# 882  female  22.0      0  10.5167        S
# 884    male  25.0      0   7.0500        S
# 885  female  39.0      5  29.1250        Q
# 888  female   NaN      2  23.4500        S
# 890    male  32.0      0   7.7500        Q
#
# [491 rows x 9 columns]

# %%
# only getting the groups for Pclass = 1

titanic_class.get_group(1)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#         Fare Embarked
# 1    71.2833        C
# 3    53.1000        S
# 6    51.8625        S
# 11   26.5500        S
# 23   35.5000        S
# ..       ...      ...
# 871  52.5542        S
# 872   5.0000        S
# 879  83.1583        C
# 887  30.0000        S
# 889  30.0000        C
#
# [216 rows x 9 columns]

# %%
titanic.groupby("Pclass").get_group(1)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  Parch  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#         Fare Embarked
# 1    71.2833        C
# 3    53.1000        S
# 6    51.8625        S
# 11   26.5500        S
# 23   35.5000        S
# ..       ...      ...
# 871  52.5542        S
# 872   5.0000        S
# 879  83.1583        C
# 887  30.0000        S
# 889  30.0000        C
#
# [216 rows x 9 columns]

# %% [markdown]
# ### Aggregate

# %%
# total number of people who survived per class
titanic_class.sum()
# Out:
#         PassengerId  Survived      Age  Parch        Fare
# Pclass
# 1             99705       136  7111.42     77  18177.4125
# 2             82056        87  5168.83     70   3801.8417
# 3            215625       119  8924.92    193   6714.6951

# %%
titanic.groupby("Pclass")["Survived"].sum()
# Out:
# Pclass
# 1    136
# 2     87
# 3    119
# Name: Survived, dtype: int64

# %%
# average age of people from different classes
titanic_class.mean()
# Out:
#         PassengerId  Survived        Age     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.393075  13.675550

# %%
titanic.groupby("Pclass")["Age"].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
# max ticket fare paid
titanic_class.max()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-f7908284135c> in <module>
#       1 # max ticket fare paid
# ----> 2 titanic_class.max()
#
# ~\venvs\py39\Lib\site-packages\pandas\core\groupby\groupby.py in max(self, numeric_only, min_count)
#    1674     @doc(_groupby_agg_method_template, fname="max", no=False, mc=-1)
#    1675     def max(self, numeric_only: bool = False, min_count: int = -1):
# -> 1676         return self._agg_general(
#    1677             numeric_only=numeric_only, min_count=min_count, alias="max", npfunc=np.max
#    1678         )
#
# ~\venvs\py39\Lib\site-packages\pandas\core\groupby\groupby.py in _agg_general(self, numeric_only, min_count, alias, npfunc)
#    1022             result = None
#    1023             try:
# -> 1024                 result = self._cython_agg_general(
#    1025                     how=alias,
#    1026                     alt=npfunc,
#
# ~\venvs\py39\Lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1013         self, how: str, alt=None, numeric_only: bool = True, min_count: int = -1
#    1014     ) -> DataFrame:
# -> 1015         agg_mgr = self._cython_agg_blocks(
#    1016             how, alt=alt, numeric_only=numeric_only, min_count=min_count
#    1017         )
#
# ~\venvs\py39\Lib\site-packages\pandas\core\groupby\generic.py in _cython_agg_blocks(self, how, alt, numeric_only, min_count)
#    1109         #  continue and exclude the block
#    1110         # NotImplementedError -> "ohlc" with wrong dtype
# -> 1111         new_mgr = data.apply(blk_func, ignore_failures=True)
#    1112
#    1113         if not len(new_mgr):
#
# ~\venvs\py39\Lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     423             try:
#     424                 if callable(f):
# --> 425                     applied = b.apply(f, **kwargs)
#     426                 else:
#     427                     applied = getattr(b, f)(**kwargs)
#
# ~\venvs\py39\Lib\site-packages\pandas\core\internals\blocks.py in apply(self, func, **kwargs)
#     378             result = func(self.values, **kwargs)
#     379
# --> 380         return self._split_op_result(result)
#     381
#     382     def reduce(self, func, ignore_failures: bool = False) -> List["Block"]:
#
# ~\venvs\py39\Lib\site-packages\pandas\core\internals\blocks.py in _split_op_result(self, result)
#     414
#     415         if not isinstance(result, Block):
# --> 416             result = self.make_block(result)
#     417
#     418         return [result]
#
# ~\venvs\py39\Lib\site-packages\pandas\core\internals\blocks.py in make_block(self, values, placement)
#     284             values = _block_shape(values, ndim=self.ndim)
#     285
# --> 286         return make_block(values, placement=placement, ndim=self.ndim)
#     287
#     288     def make_block_same_class(self, values, placement=None, ndim=None):
#
# ~\venvs\py39\Lib\site-packages\pandas\core\internals\blocks.py in make_block(values, placement, klass, ndim, dtype)
#    2730         values = DatetimeArray._simple_new(values, dtype=dtype)
#    2731
# -> 2732     return klass(values, ndim=ndim, placement=placement)
#    2733
#    2734
#
# ~\venvs\py39\Lib\site-packages\pandas\core\internals\blocks.py in __init__(self, values, placement, ndim)
#     140
#     141         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
# --> 142             raise ValueError(
#     143                 f"Wrong number of items passed {len(self.values)}, "
#     144                 f"placement implies {len(self.mgr_locs)}"
#
# ValueError: Wrong number of items passed 2, placement implies 3

# %%
titanic.groupby("Pclass")["Fare"].max()
# Out:
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
# multiple functions at once
titanic_class["Fare"].agg({"Fare" : ['sum', 'max']})
# Out:
#               Fare
#                sum       max
# Pclass
# 1       18177.4125  512.3292
# 2        3801.8417   73.5000
# 3        6714.6951   69.5500

# %% [markdown]
# ### Filter

# %%
# What is the average fare when a group has its average age greater than or less 38?

# %%
titanic_class.filter( lambda x : x["Age"].mean() > 38.0)
# Out:
#      PassengerId  Survived                                               Name  \
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6              7         0                            McCarthy, Mr. Timothy J
# 11            12         1                           Bonnell, Miss. Elizabeth
# 23            24         1                       Sloper, Mr. William Thompson
# ..           ...       ...                                                ...
# 871          872         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872          873         0                           Carlsson, Mr. Frans Olof
# 879          880         1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887          888         1                       Graham, Miss. Margaret Edith
# 889          890         1                              Behr, Mr. Karl Howell
#
#         Sex   Age  Parch     Fare Embarked
# 1    female  38.0      0  71.2833        C
# 3    female  35.0      0  53.1000        S
# 6      male  54.0      0  51.8625        S
# 11   female  58.0      0  26.5500        S
# 23     male  28.0      0  35.5000        S
# ..      ...   ...    ...      ...      ...
# 871  female  47.0      1  52.5542        S
# 872    male  33.0      0   5.0000        S
# 879  female  56.0      1  83.1583        C
# 887  female  19.0      0  30.0000        S
# 889    male  26.0      0  30.0000        C
#
# [216 rows x 8 columns]

# %%
titanic.groupby("Pclass").filter(["Age"].mean > 38.0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-bb5d5c8c0c09> in <module>
# ----> 1 titanic.groupby("Pclass").filter(["Age"].mean > 38.0)
#
# AttributeError: 'list' object has no attribute 'mean'

# %%
titanic_class.filter( lambda x : x["Age"].mean() < 38.0)
# Out:
#      PassengerId  Survived                                      Name     Sex  \
# 0              1         0                   Braund, Mr. Owen Harris    male
# 2              3         1                    Heikkinen, Miss. Laina  female
# 4              5         0                  Allen, Mr. William Henry    male
# 5              6         0                          Moran, Mr. James    male
# 7              8         0            Palsson, Master. Gosta Leonard    male
# ..           ...       ...                                       ...     ...
# 884          885         0                    Sutehall, Mr. Henry Jr    male
# 885          886         0      Rice, Mrs. William (Margaret Norton)  female
# 886          887         0                     Montvila, Rev. Juozas    male
# 888          889         0  Johnston, Miss. Catherine Helen "Carrie"  female
# 890          891         0                       Dooley, Mr. Patrick    male
#
#       Age  Parch     Fare Embarked
# 0    22.0      0   7.2500        S
# 2    26.0      0   7.9250        S
# 4    35.0      0   8.0500        S
# 5     NaN      0   8.4583        Q
# 7     2.0      1  21.0750        S
# ..    ...    ...      ...      ...
# 884  25.0      0   7.0500        S
# 885  39.0      5  29.1250        Q
# 886  27.0      0  13.0000        S
# 888   NaN      2  23.4500        S
# 890  32.0      0   7.7500        Q
#
# [675 rows x 8 columns]

# %%
titanic_class.filter( lambda x : x["Age"].mean() > 38.0)["Fare"].mean()
# Out:
# 84.15468749999992

# %%
titanic_class.filter( lambda x : x["Age"].mean() < 38.0)["Fare"].mean()
# Out:
# 15.580054518518512

# %% [markdown]
# ### Transform

# %%
# Which of the passengers paid a fare that is higher than the average for their ticket class?

# %%
titanic["avg_fare_class"] = titanic.groupby("Pclass")["Fare"].transform(lambda x : x.mean())

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  Parch  \
# 0                            Braund, Mr. Owen Harris    male  22.0      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#       Fare Embarked  avg_fare_class
# 0   7.2500        S       13.675550
# 1  71.2833        C       84.154687
# 2   7.9250        S       13.675550
# 3  53.1000        S       84.154687
# 4   8.0500        S       13.675550

# %%
titanic["fare_above_avg"] = titanic["avg_fare_class"] < titanic["Fare"]
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  Parch  \
# 0                              Braund, Mr. Owen Harris    male  22.0      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      2
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#         Fare Embarked  avg_fare_class  fare_above_avg
# 0     7.2500        S       13.675550           False
# 1    71.2833        C       84.154687           False
# 2     7.9250        S       13.675550           False
# 3    53.1000        S       84.154687           False
# 4     8.0500        S       13.675550           False
# ..       ...      ...             ...             ...
# 886  13.0000        S       20.662183           False
# 887  30.0000        S       84.154687           False
# 888  23.4500        S       13.675550            True
# 889  30.0000        C       84.154687           False
# 890   7.7500        Q       13.675550           False
#
# [891 rows x 11 columns]

# %% [markdown]
# ### Multi-Index

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  Parch  \
# 0                            Braund, Mr. Owen Harris    male  22.0      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      0
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#       Fare Embarked  avg_fare_class  fare_above_avg
# 0   7.2500        S       13.675550           False
# 1  71.2833        C       84.154687           False
# 2   7.9250        S       13.675550           False
# 3  53.1000        S       84.154687           False
# 4   8.0500        S       13.675550           False

# %%
titanic.loc[:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  Parch  \
# 0                            Braund, Mr. Owen Harris    male  22.0      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      0
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#       Fare Embarked  avg_fare_class  fare_above_avg
# 0   7.2500        S       13.675550           False
# 1  71.2833        C       84.154687           False
# 2   7.9250        S       13.675550           False

# %%
# setting name and sex as indices

titanic_multi = titanic.set_index(["Embarked", "Sex"])

# %%
titanic_multi.head()
# Out:
#                  PassengerId  Survived  Pclass  \
# Embarked Sex
# S        male              1         0       3
# C        female            2         1       1
# S        female            3         1       3
#          female            4         1       1
#          male              5         0       3
#
#                                                               Name   Age  \
# Embarked Sex
# S        male                              Braund, Mr. Owen Harris  22.0
# C        female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# S        female                             Heikkinen, Miss. Laina  26.0
#          female       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
#          male                             Allen, Mr. William Henry  35.0
#
#                  Parch     Fare  avg_fare_class  fare_above_avg
# Embarked Sex
# S        male        0   7.2500       13.675550           False
# C        female      0  71.2833       84.154687           False
# S        female      0   7.9250       13.675550           False
#          female      0  53.1000       84.154687           False
#          male        0   8.0500       13.675550           False

# %%
# groupby using two columns
tita_df = titanic_multi.groupby(["Pclass", "Sex"]).mean()
tita_df
# Out:
#                PassengerId  Survived        Age     Parch        Fare  \
# Pclass Sex
# 1      female   469.212766  0.968085  34.611765  0.457447  106.125798
#        male     455.729508  0.368852  41.281386  0.278689   67.226127
# 2      female   443.105263  0.921053  28.722973  0.605263   21.970121
#        male     447.962963  0.157407  30.740707  0.222222   19.741782
# 3      female   399.729167  0.500000  21.750000  0.798611   16.118810
#        male     455.515850  0.135447  26.507589  0.224784   12.661633
#
#                avg_fare_class  fare_above_avg
# Pclass Sex
# 1      female       84.154688        0.457447
#        male         84.154688        0.188525
# 2      female       20.662183        0.539474
#        male         20.662183        0.361111
# 3      female       13.675550        0.479167
#        male         13.675550        0.239193
